# %%
import pandas as pd

og_df = pd.read_pickle('../df.pkl') 
count_df1 = og_df.groupby(['transcript_id', 'transcript_position']).size().reset_index(name='read_count')
count_df2 = og_df.groupby(['transcript_id']).size().reset_index(name='expression_count') #most genes are likely to produce unique transcripts
df = og_df.merge(count_df1, on=['transcript_id', 'transcript_position'])
df = df.merge(count_df2, on=['transcript_id'])

agg_functions = {
    'gene_id': 'first',
    'combined nucleotides': 'first',
    'dwelling_time1': 'mean',
    'sd1': 'mean',
    'mean1': 'mean',
    'dwelling_time2': 'mean',
    'sd2': 'mean',
    'mean2': 'mean',
    'dwelling_time3': 'mean',
    'sd3': 'mean',
    'mean3': 'mean',
    'label': 'sum'
}

summary_df = og_df.groupby(['transcript_id', 'transcript_position']).agg(agg_functions).reset_index()

summary_df = summary_df.merge(count_df1, on=['transcript_id', 'transcript_position'])
summary_df = summary_df.merge(count_df2, on=['transcript_id'])

summary_df['label_percentage'] = summary_df['label'] / summary_df['read_count'] * 100
summary_df = summary_df.rename(columns={'label': 'label_sum'})
summary_df['label'] = summary_df['label_percentage'].apply(lambda x: 0 if x == 0 else 1)

# %%
agg_functions = {
    'gene_id': 'first',
    'combined nucleotides': 'first',
    'dwelling_time1': 'mean',
    'sd1': 'mean',
    'mean1': 'mean',
    'dwelling_time2': 'mean',
    'sd2': 'mean',
    'mean2': 'mean',
    'dwelling_time3': 'mean',
    'sd3': 'mean',
    'mean3': 'mean',
    'label': 'first'
}

summary_df1 = og_df.groupby(['transcript_id', 'transcript_position']).agg(agg_functions).reset_index()
summary_df1['label'].equals(summary_df['label'])
# Out:
# True

# %%
summary_df['label_percentage'].unique()
# Out:
# array([  0., 100.])

# %%
summary_df = summary_df.drop(columns=['label_percentage', 'label_sum'])
summary_df
# Out:
#           transcript_id  transcript_position          gene_id  \
# 0       ENST00000000233                  244  ENSG00000004059
# 1       ENST00000000233                  261  ENSG00000004059
# 2       ENST00000000233                  316  ENSG00000004059
# 3       ENST00000000233                  332  ENSG00000004059
# 4       ENST00000000233                  368  ENSG00000004059
# ...                 ...                  ...              ...
# 121833  ENST00000641834                 1348  ENSG00000167747
# 121834  ENST00000641834                 1429  ENSG00000167747
# 121835  ENST00000641834                 1531  ENSG00000167747
# 121836  ENST00000641834                 1537  ENSG00000167747
# 121837  ENST00000641834                 1693  ENSG00000167747
#
#        combined nucleotides  dwelling_time1       sd1       mean1  \
# 0                   AAGACCA        0.008264  4.223784  123.702703
# 1                   CAAACTG        0.006609  3.216424  109.681395
# 2                   GAAACAG        0.007570  2.940541  105.475676
# 3                   AGAACAT        0.010620  6.476350  129.355000
# 4                   AGGACAA        0.010701  6.415051  117.924242
# ...                     ...             ...       ...         ...
# 121833              GGGACAT        0.009594  3.294164  118.232877
# 121834              CTGACAC        0.008393  4.511014  110.969565
# 121835              TGGACAC        0.008161  3.918438  113.968750
# 121836              CTGACCA        0.008044  3.191228  109.354386
# 121837              TTGACAT        0.008788  4.090577  105.807692
#
#         dwelling_time2       sd2       mean2  dwelling_time3       sd3  \
# 0             0.009373  7.382162  125.913514        0.007345  4.386989
# 1             0.006813  3.226535  107.889535        0.007710  3.016599
# 2             0.007416  3.642703   98.947027        0.007555  2.087146
# 3             0.008632  2.899200   97.836500        0.006101  2.236520
# 4             0.011479  5.870303  121.954545        0.010019  4.260253
# ...                ...       ...         ...             ...       ...
# 121833        0.007300  4.929726  116.342466        0.006555  4.005616
# 121834        0.010305  9.105797  114.927536        0.005568  3.644638
# 121835        0.006877  4.759688  113.562500        0.006410  2.181563
# 121836        0.007419  6.552982  123.263158        0.006472  2.540877
# 121837        0.006908  8.702885  113.134615        0.008337  2.576731
#
#             mean3  read_count  expression_count  label
# 0       80.570270         185              3449      0
# 1       94.290698         172              3449      0
# 2       89.364324         185              3449      0
# 3       89.154000         200              3449      0
# 4       85.178788         198              3449      0
# ...           ...         ...               ...    ...
# 121833  82.004110          73              1323      1
# 121834  80.497101          69              1323      0
# 121835  84.190625          64              1323      1
# 121836  82.289474          57              1323      0
# 121837  78.536538          52              1323      0
#
# [121838 rows x 16 columns]

# %%
print(df['label'].value_counts())
print(summary_df['label'].value_counts())
# Out:
# label
# 0    10527532
# 1      499574
# Name: count, dtype: int64
# label
# 0    116363
# 1      5475
# Name: count, dtype: int64

# %% [markdown]
# ### 5-mer feature and binary features for first and last letters

# %%
# function to convert features
def sequence_to_features(seq):
    """
    Convert a 7-letter sequence into binary features for the first and last letters.
    
    Parameters:
    - seq: A string of 7 letters (A, T, C, G)
    
    Returns:
    - A dictionary with binary features for the first and last letters.
    """
    letters = ['A', 'T', 'C', 'G']
    features = {}
    
    first_char = seq[0]
    last_char = seq[-1]
    
    for letter in letters:
        features[f"1{letter}"] = first_char == letter
        features[f"7{letter}"] = last_char == letter
            
    return features

# %%
new_df = summary_df.copy()

feature_dicts = new_df['combined nucleotides'].apply(sequence_to_features)
features_df = feature_dicts.apply(pd.Series)
new_df = pd.concat([new_df, features_df], axis=1)

# %%
new_df
# Out:
#           transcript_id  transcript_position          gene_id  \
# 0       ENST00000000233                  244  ENSG00000004059
# 1       ENST00000000233                  261  ENSG00000004059
# 2       ENST00000000233                  316  ENSG00000004059
# 3       ENST00000000233                  332  ENSG00000004059
# 4       ENST00000000233                  368  ENSG00000004059
# ...                 ...                  ...              ...
# 121833  ENST00000641834                 1348  ENSG00000167747
# 121834  ENST00000641834                 1429  ENSG00000167747
# 121835  ENST00000641834                 1531  ENSG00000167747
# 121836  ENST00000641834                 1537  ENSG00000167747
# 121837  ENST00000641834                 1693  ENSG00000167747
#
#        combined nucleotides  dwelling_time1       sd1       mean1  \
# 0                   AAGACCA        0.008264  4.223784  123.702703
# 1                   CAAACTG        0.006609  3.216424  109.681395
# 2                   GAAACAG        0.007570  2.940541  105.475676
# 3                   AGAACAT        0.010620  6.476350  129.355000
# 4                   AGGACAA        0.010701  6.415051  117.924242
# ...                     ...             ...       ...         ...
# 121833              GGGACAT        0.009594  3.294164  118.232877
# 121834              CTGACAC        0.008393  4.511014  110.969565
# 121835              TGGACAC        0.008161  3.918438  113.968750
# 121836              CTGACCA        0.008044  3.191228  109.354386
# 121837              TTGACAT        0.008788  4.090577  105.807692
#
#         dwelling_time2       sd2       mean2  ...  expression_count  label  \
# 0             0.009373  7.382162  125.913514  ...              3449      0
# 1             0.006813  3.226535  107.889535  ...              3449      0
# 2             0.007416  3.642703   98.947027  ...              3449      0
# 3             0.008632  2.899200   97.836500  ...              3449      0
# 4             0.011479  5.870303  121.954545  ...              3449      0
# ...                ...       ...         ...  ...               ...    ...
# 121833        0.007300  4.929726  116.342466  ...              1323      1
# 121834        0.010305  9.105797  114.927536  ...              1323      0
# 121835        0.006877  4.759688  113.562500  ...              1323      1
# 121836        0.007419  6.552982  123.263158  ...              1323      0
# 121837        0.006908  8.702885  113.134615  ...              1323      0
#
#            1A     7A     1T     7T     1C     7C     1G     7G
# 0        True   True  False  False  False  False  False  False
# 1       False  False  False  False   True  False  False   True
# 2       False  False  False  False  False  False   True   True
# 3        True  False  False   True  False  False  False  False
# 4        True   True  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...
# 121833  False  False  False   True  False  False   True  False
# 121834  False  False  False  False   True   True  False  False
# 121835  False  False   True  False  False   True  False  False
# 121836  False   True  False  False   True  False  False  False
# 121837  False  False   True   True  False  False  False  False
#
# [121838 rows x 24 columns]

# %%
new_df['5-mer'] = new_df['combined nucleotides'].apply(lambda x: x[1:-1])
new_df.groupby(['5-mer'])['label'].sum().sort_values(ascending=False)
# Out:
# 5-mer
# GGACT    1440
# GAACT     783
# GGACA     691
# GGACC     552
# AGACT     525
# TGACT     430
# AAACT     255
# GAACA     187
# AGACA     147
# GAACC     124
# TGACC      90
# TAACT      71
# TGACA      68
# AGACC      60
# AAACA      38
# AAACC      11
# TAACC       2
# TAACA       1
# Name: label, dtype: int64

# %%
new_df
# Out:
#           transcript_id  transcript_position          gene_id  \
# 0       ENST00000000233                  244  ENSG00000004059
# 1       ENST00000000233                  261  ENSG00000004059
# 2       ENST00000000233                  316  ENSG00000004059
# 3       ENST00000000233                  332  ENSG00000004059
# 4       ENST00000000233                  368  ENSG00000004059
# ...                 ...                  ...              ...
# 121833  ENST00000641834                 1348  ENSG00000167747
# 121834  ENST00000641834                 1429  ENSG00000167747
# 121835  ENST00000641834                 1531  ENSG00000167747
# 121836  ENST00000641834                 1537  ENSG00000167747
# 121837  ENST00000641834                 1693  ENSG00000167747
#
#        combined nucleotides  dwelling_time1       sd1       mean1  \
# 0                   AAGACCA        0.008264  4.223784  123.702703
# 1                   CAAACTG        0.006609  3.216424  109.681395
# 2                   GAAACAG        0.007570  2.940541  105.475676
# 3                   AGAACAT        0.010620  6.476350  129.355000
# 4                   AGGACAA        0.010701  6.415051  117.924242
# ...                     ...             ...       ...         ...
# 121833              GGGACAT        0.009594  3.294164  118.232877
# 121834              CTGACAC        0.008393  4.511014  110.969565
# 121835              TGGACAC        0.008161  3.918438  113.968750
# 121836              CTGACCA        0.008044  3.191228  109.354386
# 121837              TTGACAT        0.008788  4.090577  105.807692
#
#         dwelling_time2       sd2       mean2  ...  label     1A     7A     1T  \
# 0             0.009373  7.382162  125.913514  ...      0   True   True  False
# 1             0.006813  3.226535  107.889535  ...      0  False  False  False
# 2             0.007416  3.642703   98.947027  ...      0  False  False  False
# 3             0.008632  2.899200   97.836500  ...      0   True  False  False
# 4             0.011479  5.870303  121.954545  ...      0   True   True  False
# ...                ...       ...         ...  ...    ...    ...    ...    ...
# 121833        0.007300  4.929726  116.342466  ...      1  False  False  False
# 121834        0.010305  9.105797  114.927536  ...      0  False  False  False
# 121835        0.006877  4.759688  113.562500  ...      1  False  False   True
# 121836        0.007419  6.552982  123.263158  ...      0  False   True  False
# 121837        0.006908  8.702885  113.134615  ...      0  False  False   True
#
#            7T     1C     7C     1G     7G  5-mer
# 0       False  False  False  False  False  AGACC
# 1       False   True  False  False   True  AAACT
# 2       False  False  False   True   True  AAACA
# 3        True  False  False  False  False  GAACA
# 4       False  False  False  False  False  GGACA
# ...       ...    ...    ...    ...    ...    ...
# 121833   True  False  False   True  False  GGACA
# 121834  False   True   True  False  False  TGACA
# 121835  False  False   True  False  False  GGACA
# 121836  False   True  False  False  False  TGACC
# 121837   True  False  False  False  False  TGACA
#
# [121838 rows x 25 columns]

# %% [markdown]
# ### Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

combined = new_df.copy()

label_encoder = LabelEncoder()
combined['transcript_id'] = label_encoder.fit_transform(combined['transcript_id'])
combined['gene_id'] = label_encoder.fit_transform(combined['gene_id'])
combined
# Out:
#         transcript_id  transcript_position  gene_id combined nucleotides  \
# 0                   0                  244       10              AAGACCA
# 1                   0                  261       10              CAAACTG
# 2                   0                  316       10              GAAACAG
# 3                   0                  332       10              AGAACAT
# 4                   0                  368       10              AGGACAA
# ...               ...                  ...      ...                  ...
# 121833           5332                 1348     2764              GGGACAT
# 121834           5332                 1429     2764              CTGACAC
# 121835           5332                 1531     2764              TGGACAC
# 121836           5332                 1537     2764              CTGACCA
# 121837           5332                 1693     2764              TTGACAT
#
#         dwelling_time1       sd1       mean1  dwelling_time2       sd2  \
# 0             0.008264  4.223784  123.702703        0.009373  7.382162
# 1             0.006609  3.216424  109.681395        0.006813  3.226535
# 2             0.007570  2.940541  105.475676        0.007416  3.642703
# 3             0.010620  6.476350  129.355000        0.008632  2.899200
# 4             0.010701  6.415051  117.924242        0.011479  5.870303
# ...                ...       ...         ...             ...       ...
# 121833        0.009594  3.294164  118.232877        0.007300  4.929726
# 121834        0.008393  4.511014  110.969565        0.010305  9.105797
# 121835        0.008161  3.918438  113.968750        0.006877  4.759688
# 121836        0.008044  3.191228  109.354386        0.007419  6.552982
# 121837        0.008788  4.090577  105.807692        0.006908  8.702885
#
#              mean2  ...  label     1A     7A     1T     7T     1C     7C  \
# 0       125.913514  ...      0   True   True  False  False  False  False
# 1       107.889535  ...      0  False  False  False  False   True  False
# 2        98.947027  ...      0  False  False  False  False  False  False
# 3        97.836500  ...      0   True  False  False   True  False  False
# 4       121.954545  ...      0   True   True  False  False  False  False
# ...            ...  ...    ...    ...    ...    ...    ...    ...    ...
# 121833  116.342466  ...      1  False  False  False   True  False  False
# 121834  114.927536  ...      0  False  False  False  False   True   True
# 121835  113.562500  ...      1  False  False   True  False  False   True
# 121836  123.263158  ...      0  False   True  False  False   True  False
# 121837  113.134615  ...      0  False  False   True   True  False  False
#
#            1G     7G  5-mer
# 0       False  False  AGACC
# 1       False   True  AAACT
# 2        True   True  AAACA
# 3       False  False  GAACA
# 4       False  False  GGACA
# ...       ...    ...    ...
# 121833   True  False  GGACA
# 121834  False  False  TGACA
# 121835  False  False  GGACA
# 121836  False  False  TGACC
# 121837  False  False  TGACA
#
# [121838 rows x 25 columns]

# %%
combined = pd.get_dummies(combined, columns=['5-mer'], drop_first=False)
combined
# Out:
#         transcript_id  transcript_position  gene_id combined nucleotides  \
# 0                   0                  244       10              AAGACCA
# 1                   0                  261       10              CAAACTG
# 2                   0                  316       10              GAAACAG
# 3                   0                  332       10              AGAACAT
# 4                   0                  368       10              AGGACAA
# ...               ...                  ...      ...                  ...
# 121833           5332                 1348     2764              GGGACAT
# 121834           5332                 1429     2764              CTGACAC
# 121835           5332                 1531     2764              TGGACAC
# 121836           5332                 1537     2764              CTGACCA
# 121837           5332                 1693     2764              TTGACAT
#
#         dwelling_time1       sd1       mean1  dwelling_time2       sd2  \
# 0             0.008264  4.223784  123.702703        0.009373  7.382162
# 1             0.006609  3.216424  109.681395        0.006813  3.226535
# 2             0.007570  2.940541  105.475676        0.007416  3.642703
# 3             0.010620  6.476350  129.355000        0.008632  2.899200
# 4             0.010701  6.415051  117.924242        0.011479  5.870303
# ...                ...       ...         ...             ...       ...
# 121833        0.009594  3.294164  118.232877        0.007300  4.929726
# 121834        0.008393  4.511014  110.969565        0.010305  9.105797
# 121835        0.008161  3.918438  113.968750        0.006877  4.759688
# 121836        0.008044  3.191228  109.354386        0.007419  6.552982
# 121837        0.008788  4.090577  105.807692        0.006908  8.702885
#
#              mean2  ...  5-mer_GAACT  5-mer_GGACA  5-mer_GGACC  5-mer_GGACT  \
# 0       125.913514  ...        False        False        False        False
# 1       107.889535  ...        False        False        False        False
# 2        98.947027  ...        False        False        False        False
# 3        97.836500  ...        False        False        False        False
# 4       121.954545  ...        False         True        False        False
# ...            ...  ...          ...          ...          ...          ...
# 121833  116.342466  ...        False         True        False        False
# 121834  114.927536  ...        False        False        False        False
# 121835  113.562500  ...        False         True        False        False
# 121836  123.263158  ...        False        False        False        False
# 121837  113.134615  ...        False        False        False        False
#
#         5-mer_TAACA  5-mer_TAACC  5-mer_TAACT  5-mer_TGACA  5-mer_TGACC  \
# 0             False        False        False        False        False
# 1             False        False        False        False        False
# 2             False        False        False        False        False
# 3             False        False        False        False        False
# 4             False        False        False        False        False
# ...             ...          ...          ...          ...          ...
# 121833        False        False        False        False        False
# 121834        False        False        False         True        False
# 121835        False        False        False        False        False
# 121836        False        False        False        False         True
# 121837        False        False        False         True        False
#
#         5-mer_TGACT
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 121833        False
# 121834        False
# 121835        False
# 121836        False
# 121837        False
#
# [121838 rows x 42 columns]

# %%
combined = combined.drop(columns=['combined nucleotides'])
combined
# Out:
#         transcript_id  transcript_position  gene_id  dwelling_time1       sd1  \
# 0                   0                  244       10        0.008264  4.223784
# 1                   0                  261       10        0.006609  3.216424
# 2                   0                  316       10        0.007570  2.940541
# 3                   0                  332       10        0.010620  6.476350
# 4                   0                  368       10        0.010701  6.415051
# ...               ...                  ...      ...             ...       ...
# 121833           5332                 1348     2764        0.009594  3.294164
# 121834           5332                 1429     2764        0.008393  4.511014
# 121835           5332                 1531     2764        0.008161  3.918438
# 121836           5332                 1537     2764        0.008044  3.191228
# 121837           5332                 1693     2764        0.008788  4.090577
#
#              mean1  dwelling_time2       sd2       mean2  dwelling_time3  ...  \
# 0       123.702703        0.009373  7.382162  125.913514        0.007345  ...
# 1       109.681395        0.006813  3.226535  107.889535        0.007710  ...
# 2       105.475676        0.007416  3.642703   98.947027        0.007555  ...
# 3       129.355000        0.008632  2.899200   97.836500        0.006101  ...
# 4       117.924242        0.011479  5.870303  121.954545        0.010019  ...
# ...            ...             ...       ...         ...             ...  ...
# 121833  118.232877        0.007300  4.929726  116.342466        0.006555  ...
# 121834  110.969565        0.010305  9.105797  114.927536        0.005568  ...
# 121835  113.968750        0.006877  4.759688  113.562500        0.006410  ...
# 121836  109.354386        0.007419  6.552982  123.263158        0.006472  ...
# 121837  105.807692        0.006908  8.702885  113.134615        0.008337  ...
#
#         5-mer_GAACT  5-mer_GGACA  5-mer_GGACC  5-mer_GGACT  5-mer_TAACA  \
# 0             False        False        False        False        False
# 1             False        False        False        False        False
# 2             False        False        False        False        False
# 3             False        False        False        False        False
# 4             False         True        False        False        False
# ...             ...          ...          ...          ...          ...
# 121833        False         True        False        False        False
# 121834        False        False        False        False        False
# 121835        False         True        False        False        False
# 121836        False        False        False        False        False
# 121837        False        False        False        False        False
#
#         5-mer_TAACC  5-mer_TAACT  5-mer_TGACA  5-mer_TGACC  5-mer_TGACT
# 0             False        False        False        False        False
# 1             False        False        False        False        False
# 2             False        False        False        False        False
# 3             False        False        False        False        False
# 4             False        False        False        False        False
# ...             ...          ...          ...          ...          ...
# 121833        False        False        False        False        False
# 121834        False        False         True        False        False
# 121835        False        False        False        False        False
# 121836        False        False        False         True        False
# 121837        False        False         True        False        False
#
# [121838 rows x 41 columns]

# %%
combined.value_counts('gene_id')
# Out:
# gene_id
# 1528    274
# 977     253
# 2632    250
# 2005    230
# 1929    229
#        ...
# 857       1
# 863       1
# 887       1
# 2800      1
# 1412      1
# Name: count, Length: 3852, dtype: int64

# %% [markdown]
# ### Resampling Methods

# %%
X = combined.drop('label', axis=1)
y = combined['label']

# %%
X
# Out:
#         transcript_id  transcript_position  gene_id  dwelling_time1       sd1  \
# 0                   0                  244       10        0.008264  4.223784
# 1                   0                  261       10        0.006609  3.216424
# 2                   0                  316       10        0.007570  2.940541
# 3                   0                  332       10        0.010620  6.476350
# 4                   0                  368       10        0.010701  6.415051
# ...               ...                  ...      ...             ...       ...
# 121833           5332                 1348     2764        0.009594  3.294164
# 121834           5332                 1429     2764        0.008393  4.511014
# 121835           5332                 1531     2764        0.008161  3.918438
# 121836           5332                 1537     2764        0.008044  3.191228
# 121837           5332                 1693     2764        0.008788  4.090577
#
#              mean1  dwelling_time2       sd2       mean2  dwelling_time3  ...  \
# 0       123.702703        0.009373  7.382162  125.913514        0.007345  ...
# 1       109.681395        0.006813  3.226535  107.889535        0.007710  ...
# 2       105.475676        0.007416  3.642703   98.947027        0.007555  ...
# 3       129.355000        0.008632  2.899200   97.836500        0.006101  ...
# 4       117.924242        0.011479  5.870303  121.954545        0.010019  ...
# ...            ...             ...       ...         ...             ...  ...
# 121833  118.232877        0.007300  4.929726  116.342466        0.006555  ...
# 121834  110.969565        0.010305  9.105797  114.927536        0.005568  ...
# 121835  113.968750        0.006877  4.759688  113.562500        0.006410  ...
# 121836  109.354386        0.007419  6.552982  123.263158        0.006472  ...
# 121837  105.807692        0.006908  8.702885  113.134615        0.008337  ...
#
#         5-mer_GAACT  5-mer_GGACA  5-mer_GGACC  5-mer_GGACT  5-mer_TAACA  \
# 0             False        False        False        False        False
# 1             False        False        False        False        False
# 2             False        False        False        False        False
# 3             False        False        False        False        False
# 4             False         True        False        False        False
# ...             ...          ...          ...          ...          ...
# 121833        False         True        False        False        False
# 121834        False        False        False        False        False
# 121835        False         True        False        False        False
# 121836        False        False        False        False        False
# 121837        False        False        False        False        False
#
#         5-mer_TAACC  5-mer_TAACT  5-mer_TGACA  5-mer_TGACC  5-mer_TGACT
# 0             False        False        False        False        False
# 1             False        False        False        False        False
# 2             False        False        False        False        False
# 3             False        False        False        False        False
# 4             False        False        False        False        False
# ...             ...          ...          ...          ...          ...
# 121833        False        False        False        False        False
# 121834        False        False         True        False        False
# 121835        False        False        False        False        False
# 121836        False        False        False         True        False
# 121837        False        False         True        False        False
#
# [121838 rows x 40 columns]

# %%
from imblearn.under_sampling import TomekLinks, RandomUnderSampler
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE, ADASYN
from imblearn.combine import SMOTETomek

# ADASYN followed by Tomek Links Pipeline
adasyn_tomek = Pipeline([
    ('adasyn', ADASYN(random_state=42)),
    ('tomek', TomekLinks())
])

# Dictionary of resampling methods
resampling_methods = {
    'RandomUnderSampler': RandomUnderSampler(random_state=42),
    'TomekLinks': TomekLinks(),
    'SMOTE': SMOTE(random_state=42),
    'ADASYN': ADASYN(random_state=42),
    'SMOTETomek': SMOTETomek(random_state=42),
    'ADASYN_Tomek': adasyn_tomek
}

# %% [markdown]
# ### XGBoost with GroupShuffleSplit

# %%
import numpy as np
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import roc_auc_score, precision_recall_curve, auc
import xgboost as xgb

# Initialize GroupShuffleSplit
group_shuffle_split = GroupShuffleSplit(n_splits=5, test_size=0.2, random_state=42)

# Model initialization
xgb_model = xgb.XGBClassifier(n_estimators=300, random_state=42, learning_rate=0.1, max_depth=5)

# Drop 'gene_id' from X
X_no_gene_id = X.drop(columns=['gene_id'])

# Loop through each resampling method
for method_name, resampler in resampling_methods.items():
    print(f"Results for {method_name}:")
    
    roc_aucs = []  # List to store ROC AUC scores for each fold
    pr_aucs = []   # List to store PR AUC scores for each fold
    avg_scores = [] # List to store the average of ROC AUC and PR AUC scores for each fold
    
    # Loop through each fold
    for train_index, valid_index in group_shuffle_split.split(X, y, groups=X['gene_id']):
        X_train_fold, X_valid_fold = X_no_gene_id.iloc[train_index], X_no_gene_id.iloc[valid_index]
        y_train_fold, y_valid_fold = y.iloc[train_index], y.iloc[valid_index]
        
        # Initialize the scaler
        scaler = MinMaxScaler()
        
        # Fit the scaler on the training data and transform both training and validation data
        X_train_fold_scaled = scaler.fit_transform(X_train_fold)
        X_valid_fold_scaled = scaler.transform(X_valid_fold)
        
        # Apply the current resampling technique
        X_resampled, y_resampled = resampler.fit_resample(X_train_fold_scaled, y_train_fold)
        
        # Train the model on the resampled data
        xgb_model.fit(X_resampled, y_resampled)
        
        # Predict on the validation set
        y_pred = xgb_model.predict_proba(X_valid_fold_scaled)[:, 1]
        
        # Compute the ROC AUC score for this fold and append to the list
        roc_auc = roc_auc_score(y_valid_fold, y_pred)
        roc_aucs.append(roc_auc)
        
        # Compute Precision-Recall curve and PR AUC score for this fold
        precision, recall, _ = precision_recall_curve(y_valid_fold, y_pred)
        pr_auc = auc(recall, precision)
        pr_aucs.append(pr_auc)
        
        # Compute the average of ROC AUC and PR AUC scores for this fold
        avg_score = (roc_auc + pr_auc) / 2
        avg_scores.append(avg_score)
    
    # Display results for the current resampling method
    print("ROC AUC scores for each fold:", roc_aucs)
    print("Mean ROC AUC score:", np.mean(roc_aucs))
    print("Standard deviation of ROC AUC scores:", np.std(roc_aucs))
    print("PR AUC scores for each fold:", pr_aucs)
    print("Mean PR AUC score:", np.mean(pr_aucs))
    print("Standard deviation of PR AUC scores:", np.std(pr_aucs))
    print("Average of ROC AUC and PR AUC scores for each fold:", avg_scores)
    print("Mean average score:", np.mean(avg_scores))
    print("Standard deviation of average scores:", np.std(avg_scores))
    print("-" * 50)
# Out:
# Results for RandomUnderSampler:
# ROC AUC scores for each fold: [0.8906834928744976, 0.9025330044261164, 0.8913792961119329, 0.8907848352281983, 0.8908846438822484]
# Mean ROC AUC score: 0.8932530545045987
# Standard deviation of ROC AUC scores: 0.004646128782186436
# PR AUC scores for each fold: [0.44036787680123524, 0.4667319898059515, 0.42171609454169423, 0.4129071524831816, 0.4234777567538124]
# Mean PR AUC score: 0.433040174077175
# Standard deviation of PR AUC scores: 0.01904650537610653
# Average of ROC AUC and PR AUC scores for each fold: [0.6655256848378663, 0.6846324971160339, 0.6565476953268136, 0.65184599385569, 0.6571812003180304]
# Mean average score: 0.6631466142908868
# Standard deviation of average scores: 0.01161153783980228
# --------------------------------------------------
# Results for TomekLinks:
# ROC AUC scores for each fold: [0.8947092831417606, 0.9056361937687386, 0.8998074033799295, 0.8962331317024385, 0.8949339361028431]
# Mean ROC AUC score: 0.898263989619142
# Standard deviation of ROC AUC scores: 0.0041129332233798095
# PR AUC scores for each fold: [0.47584905655851867, 0.49585861828515077, 0.45927740865990885, 0.4334793493225724, 0.44881768980661163]
# Mean PR AUC score: 0.46265642452655253
# Standard deviation of PR AUC scores: 0.02159009613062895
# Average of ROC AUC and PR AUC scores for each fold: [0.6852791698501396, 0.7007474060269447, 0.6795424060199191, 0.6648562405125055, 0.6718758129547273]
# Mean average score: 0.6804602070728473
# Standard deviation of average scores: 0.012270377314624813
# --------------------------------------------------
# Results for SMOTE:
# ROC AUC scores for each fold: [0.8879156070698921, 0.8972632747747272, 0.8877335530685254, 0.8815078505606367, 0.8838169433410119]
# Mean ROC AUC score: 0.8876474457629587
# Standard deviation of ROC AUC scores: 0.005383509461143215
# PR AUC scores for each fold: [0.45183919302856235, 0.4790306248447997, 0.41712242033140295, 0.4007659565637311, 0.42393284198233794]
# Mean PR AUC score: 0.43453820735016685
# Standard deviation of PR AUC scores: 0.027695659064953686
# Average of ROC AUC and PR AUC scores for each fold: [0.6698774000492272, 0.6881469498097634, 0.6524279866999642, 0.6411369035621839, 0.6538748926616749]
# Mean average score: 0.6610928265565627
# Standard deviation of average scores: 0.01633714294762978
# --------------------------------------------------
# Results for ADASYN:
# ROC AUC scores for each fold: [0.8859953738233554, 0.8955102943441164, 0.8867371744215629, 0.8778843475280322, 0.882340636549126]
# Mean ROC AUC score: 0.8856935653332385
# Standard deviation of ROC AUC scores: 0.005827081446615161
# PR AUC scores for each fold: [0.4480268994242714, 0.46982388781387097, 0.4091502890716921, 0.3965624475366206, 0.4178368554450877]
# Mean PR AUC score: 0.4282800758583085
# Standard deviation of PR AUC scores: 0.02682104731063891
# Average of ROC AUC and PR AUC scores for each fold: [0.6670111366238134, 0.6826670910789937, 0.6479437317466274, 0.6372233975323265, 0.6500887459971069]
# Mean average score: 0.6569868205957736
# Standard deviation of average scores: 0.015999481142890085
# --------------------------------------------------
# Results for SMOTETomek:
# ROC AUC scores for each fold: [0.8866701582145551, 0.8968079877160446, 0.8889800465361313, 0.8812468482988511, 0.883983785335699]
# Mean ROC AUC score: 0.8875377652202563
# Standard deviation of ROC AUC scores: 0.005309921866915631
# PR AUC scores for each fold: [0.450842463204037, 0.48177678296483406, 0.4160359801493196, 0.3972075709607815, 0.42480152606495736]
# Mean PR AUC score: 0.43413286466878587
# Standard deviation of PR AUC scores: 0.029418368611064637
# Average of ROC AUC and PR AUC scores for each fold: [0.668756310709296, 0.6892923853404394, 0.6525080133427255, 0.6392272096298164, 0.6543926557003281]
# Mean average score: 0.6608353149445211
# Standard deviation of average scores: 0.017031201101620826
# --------------------------------------------------
# Results for ADASYN_Tomek:
# ROC AUC scores for each fold: [0.8864883212645709, 0.897282840104772, 0.8870776495238697, 0.87944577595549, 0.8815513426986159]
# Mean ROC AUC score: 0.8863691859094637
# Standard deviation of ROC AUC scores: 0.006176879154000639
# PR AUC scores for each fold: [0.44741541238137855, 0.4714272651333883, 0.4117436957062773, 0.3962979062029965, 0.4202096393894199]
# Mean PR AUC score: 0.42941878376269216
# Standard deviation of PR AUC scores: 0.026768641194222724
# Average of ROC AUC and PR AUC scores for each fold: [0.6669518668229747, 0.6843550526190801, 0.6494106726150735, 0.6378718410792432, 0.6508804910440179]
# Mean average score: 0.6578939848360779
# Standard deviation of average scores: 0.016151007747721813
# --------------------------------------------------

# %% [markdown]
# ### Gradient Boosting with GroupShuffleSplit

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Model initialization using Gradient Boosting
gb_model = GradientBoostingClassifier(n_estimators=200, random_state=42, learning_rate=0.1, max_depth=5)

# Initialize GroupShuffleSplit
group_shuffle_split = GroupShuffleSplit(n_splits=5, test_size=0.2, random_state=42)

# Drop 'gene_id' from X
X_no_gene_id = X.drop(columns=['gene_id'])

# Loop through each resampling method
for method_name, resampler in resampling_methods.items():
    print(f"Results for {method_name}:")
    
    roc_aucs = []  # List to store ROC AUC scores for each fold
    pr_aucs = []   # List to store PR AUC scores for each fold
    avg_scores = [] # List to store the average of ROC AUC and PR AUC scores for each fold
    
    # Loop through each fold
    for train_index, valid_index in group_shuffle_split.split(X, y, groups=X['gene_id']):
        X_train_fold, X_valid_fold = X_no_gene_id.iloc[train_index], X_no_gene_id.iloc[valid_index]
        y_train_fold, y_valid_fold = y.iloc[train_index], y.iloc[valid_index]
        
        # Initialize the scaler
        scaler = MinMaxScaler()
        
        # Fit the scaler on the training data and transform both training and validation data
        X_train_fold_scaled = scaler.fit_transform(X_train_fold)
        X_valid_fold_scaled = scaler.transform(X_valid_fold)
        
        # Apply the current resampling technique
        X_resampled, y_resampled = resampler.fit_resample(X_train_fold_scaled, y_train_fold)
        
        # Train the model on the resampled data
        gb_model.fit(X_resampled, y_resampled)
        
        # Predict on the validation set
        y_pred = gb_model.predict_proba(X_valid_fold_scaled)[:, 1]
        
        # Compute the ROC AUC score for this fold and append to the list
        roc_auc = roc_auc_score(y_valid_fold, y_pred)
        roc_aucs.append(roc_auc)
        
        # Compute Precision-Recall curve and PR AUC score for this fold
        precision, recall, _ = precision_recall_curve(y_valid_fold, y_pred)
        pr_auc = auc(recall, precision)
        pr_aucs.append(pr_auc)
        
        # Compute the average of ROC AUC and PR AUC scores for this fold
        avg_score = (roc_auc + pr_auc) / 2
        avg_scores.append(avg_score)
    
    # Display results for the current resampling method
    print("ROC AUC scores for each fold:", roc_aucs)
    print("Mean ROC AUC score:", np.mean(roc_aucs))
    print("Standard deviation of ROC AUC scores:", np.std(roc_aucs))
    print("PR AUC scores for each fold:", pr_aucs)
    print("Mean PR AUC score:", np.mean(pr_aucs))
    print("Standard deviation of PR AUC scores:", np.std(pr_aucs))
    print("Average of ROC AUC and PR AUC scores for each fold:", avg_scores)
    print("Mean average score:", np.mean(avg_scores))
    print("Standard deviation of average scores:", np.std(avg_scores))
    print("-" * 50)
# Out:
# Results for RandomUnderSampler:
# ROC AUC scores for each fold: [0.8877166902751392, 0.9030808519527316, 0.8922574770377475, 0.8907830573155072, 0.8920635098650983]
# Mean ROC AUC score: 0.8931803172892447
# Standard deviation of ROC AUC scores: 0.00520994347582129
# PR AUC scores for each fold: [0.4387673041761462, 0.4676518111469443, 0.42523080152801784, 0.40927934526297516, 0.4207114957575153]
# Mean PR AUC score: 0.4323281515743198
# Standard deviation of PR AUC scores: 0.020028929847877523
# Average of ROC AUC and PR AUC scores for each fold: [0.6632419972256427, 0.685366331549838, 0.6587441392828827, 0.6500312012892412, 0.6563875028113069]
# Mean average score: 0.6627542344317823
# Standard deviation of average scores: 0.012083348506072684
# --------------------------------------------------
# Results for TomekLinks:
# ROC AUC scores for each fold: [0.893745875478534, 0.8985649177833748, 0.8968498337352057, 0.8974150459510892, 0.890453931347678]
# Mean ROC AUC score: 0.8954059208591764
# Standard deviation of ROC AUC scores: 0.0029454602487011634
# PR AUC scores for each fold: [0.4492471383534549, 0.47779363745075465, 0.43497545802196586, 0.4089421045224866, 0.4157134106016326]
# Mean PR AUC score: 0.4373343497900589
# Standard deviation of PR AUC scores: 0.02473061852224604
# Average of ROC AUC and PR AUC scores for each fold: [0.6714965069159945, 0.6881792776170648, 0.6659126458785858, 0.6531785752367879, 0.6530836709746553]
# Mean average score: 0.6663701353246176
# Standard deviation of average scores: 0.01305890548470243
# --------------------------------------------------
# Results for SMOTE:
# ROC AUC scores for each fold: [0.8868696716851079, 0.890790899027647, 0.8815966992442101, 0.8788857334577624, 0.8802821024110032]
# Mean ROC AUC score: 0.8836850211651461
# Standard deviation of ROC AUC scores: 0.004463397946006506
# PR AUC scores for each fold: [0.43745672116525286, 0.4623634180050756, 0.3907617550763798, 0.388213940491357, 0.4191560535487547]
# Mean PR AUC score: 0.41959037765736396
# Standard deviation of PR AUC scores: 0.02815847345830162
# Average of ROC AUC and PR AUC scores for each fold: [0.6621631964251804, 0.6765771585163612, 0.636179227160295, 0.6335498369745597, 0.6497190779798789]
# Mean average score: 0.6516376994112549
# Standard deviation of average scores: 0.016140501528173586
# --------------------------------------------------
# Results for ADASYN:
# ROC AUC scores for each fold: [0.8821560820357623, 0.8882210386396252, 0.8819770426254753, 0.8764681932823158, 0.8810012089782899]
# Mean ROC AUC score: 0.8819647131122939
# Standard deviation of ROC AUC scores: 0.0037501587604603305
# PR AUC scores for each fold: [0.42510144380912146, 0.4451989824356562, 0.39439323417626765, 0.3822614677879263, 0.4069893177215915]
# Mean PR AUC score: 0.4107888891861126
# Standard deviation of PR AUC scores: 0.022297855302357904
# Average of ROC AUC and PR AUC scores for each fold: [0.6536287629224419, 0.6667100105376407, 0.6381851384008714, 0.629364830535121, 0.6439952633499407]
# Mean average score: 0.6463768011492033
# Standard deviation of average scores: 0.012870218014009505
# --------------------------------------------------
# Results for SMOTETomek:
# ROC AUC scores for each fold: [0.88610331620476, 0.8920600855308458, 0.8824131077895676, 0.8805810199959968, 0.8847829483967392]
# Mean ROC AUC score: 0.8851880955835819
# Standard deviation of ROC AUC scores: 0.003928147695552787
# PR AUC scores for each fold: [0.4363507659666373, 0.4661772448591239, 0.39131830366639375, 0.39139561398273376, 0.41846020263667094]
# Mean PR AUC score: 0.4207404262223119
# Standard deviation of PR AUC scores: 0.028425924489591838
# Average of ROC AUC and PR AUC scores for each fold: [0.6612270410856986, 0.6791186651949849, 0.6368657057279807, 0.6359883169893653, 0.6516215755167051]
# Mean average score: 0.6529642609029469
# Standard deviation of average scores: 0.016133662663789485
# --------------------------------------------------
# Results for ADASYN_Tomek:
# ROC AUC scores for each fold: [0.8822366332687333, 0.8891349406916333, 0.8814809874275149, 0.8771730420900242, 0.8814504075909183]
# Mean ROC AUC score: 0.8822952022137647
# Standard deviation of ROC AUC scores: 0.0038574240309598848
# PR AUC scores for each fold: [0.42594567885621165, 0.45331860450434186, 0.39154899584520864, 0.384230727936244, 0.411263810617701]
# Mean PR AUC score: 0.41326156355194144
# Standard deviation of PR AUC scores: 0.024834127086191995
# Average of ROC AUC and PR AUC scores for each fold: [0.6540911560624725, 0.6712267725979876, 0.6365149916363617, 0.6307018850131341, 0.6463571091043097]
# Mean average score: 0.6477783828828532
# Standard deviation of average scores: 0.01421385849422864
# --------------------------------------------------
